# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

#take all point in population
x = [54.4,102.4,52.2,122.9,66.6,47.2,49.1]
y = [2951.5,2361.9,1762.2,3049.6,1934.3,1984.1,1800.7]
z = [12,56,63,58,79,33,57]

x = np.array(x)
y = np.array(y)
z = np.array(z)
#cList = ['red', 'blue','green']
ax = plt.axes(projection ='3d')
#currColor = cList[i]
ax.scatter(x, y, z, color='green')

#move swarm
#currParticlesVals = moveSwarm (currParticlesVals, velocity)
#update velocity
#velocity = velUpdate(currParticlesVals, pBest, velocity, i)
#plt.title("PSO: 5 Particles In 3 Positions - Schwefel function in 2D")
#filename =  'PSO-' + str(numOfPositions) + '-Positions-Line-Schwefel-2D'  +'.png'
#plt.savefig(filename)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

#take all point in population
x = [54.4,102.4,52.2,122.9,66.6,47.2,49.1]
y = [2951.5,2361.9,1762.2,3049.6,1934.3,1984.1,1800.7]
z = [12,56,63,58,79,33,57]

x = np.array(x)
y = np.array(y)
z = np.array(z)


#cList = ['red', 'blue','green']
#ax = plt.axes(projection ='3d')
#currColor = cList[i]
#ax.scatter(x, y, z, color='green')
#df_xy = pd.DataFrame(list(zip(x,y)), columns = ['time','cost'])
#plt.scatter(x,y, xlabel='time (minutes)', ylbl='cost($)')
#plt.show()
#df_xy.plot.scatter(x = 'time', y = 'cost')
#plt.show()
#df_yz = pd.DataFrame(list(zip(y,z)), columns = ['cost','quality'])
#df_yz.plot.scatter(x = 'cost', y = 'quality',label="{:.1f}".format(x,y))
#plt.scatter(y,z, x = 'cost', y = 'quality',label="{:.1f}".format(x,y))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.scatter(x,y, c = 'green')
plt.xlabel('time (minutes)')
plt.ylabel('cost (dollars)')
plt.title('Time vs. Cost')

for xy in zip (x,y):
    ax.annotate('(%s,%s)' %xy, xy=xy, textcoords='data')

plt.show()



fig = plt.figure()
ax = fig.add_subplot(111)
plt.scatter(y,z, c = 'blue')

plt.xlabel('cost (dollars)')
plt.ylabel('Quality (100 point scale)')
plt.title('Quality vs. Cost')

for yz in zip (y, z):
    ax.annotate('(%s,%s)' %yz, xy=yz, textcoords='data')

plt.show()
#move swarm
#currParticlesVals = moveSwarm (currParticlesVals, velocity)
#update velocity
#velocity = velUpdate(currParticlesVals, pBest, velocity, i)
#plt.title("PSO: 5 Particles In 3 Positions - Schwefel function in 2D")
#filename =  'PSO-' + str(numOfPositions) + '-Positions-Line-Schwefel-2D'  +'.png'
#plt.savefig(filename)
